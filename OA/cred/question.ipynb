# %% [markdown]
# q1)![image.png](attachment:image.png)

# %% [markdown]
# Q2).![image.png](attachment:image.png)

# %% [markdown]
# Q3)![image.png](attachment:image.png)

# %% [markdown]
# Q4)![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Q5)![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
