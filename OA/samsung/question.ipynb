# %% [markdown]
# Q5) aggressive cows

# %% [markdown]
# Q6)![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Q7)![image.png](attachment:image.png)

# %% [markdown]
# Q8)![image.png](attachment:image.png)

# %% [markdown]
# Q9)![image.png](attachment:image.png)

# %% [markdown]
# Q10)![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Q11)
# ![image.png](attachment:image.png)

# %% [markdown]
# Q12)
# ![image.png](attachment:image.png)
